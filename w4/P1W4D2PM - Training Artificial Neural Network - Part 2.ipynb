# %% [markdown]
# # Phase 1 - Week 4 - Day 2 PM - Training Artificial Neural Network: Part 2

# %% [markdown]
# In this notebook, we will use Fashion MNIST to demonstrate implementation of transfer learning and dropout layer.
#
# Fashion-MNIST is a dataset of Zalando's article images consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#
# *Source : [url](https://github.com/zalandoresearch/fashion-mnist)*

# %% [markdown]
# <img src='https://www.researchgate.net/profile/Saeed-Reza-Kheradpisheh/publication/342801790/figure/fig2/AS:911232181735425@1594266090934/Sample-images-from-Fashion-MNIST-dataset.png'>

# %% [markdown]
# # A. Import Libraries & Data Loading

# %%
# Import Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization

# %%
# Data Loading

## Download the dataset
fashion_mnist = tf.keras.datasets.fashion_mnist

# Data splitting
(X_train_val, y_train_val), (X_test, y_test) = fashion_mnist.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.15, random_state=42)

print('Train Size : ', X_train.shape)
print('Val Size   : ', X_val.shape)
print('Test Size  : ', X_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Train Size :  (51000, 28, 28)
# Val Size   :  (9000, 28, 28)
# Test Size  :  (10000, 28, 28)

# %%
# Define the Class Names

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Function for Visualize A Group of Images

def plot_digits(instances, n_data, images_per_row=10):
  n_rows = int(np.ceil(n_data/images_per_row))
  n_cols = images_per_row
  plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
  for row in range(n_rows):
      for col in range(n_cols):
          index = n_cols * row + col
          plt.subplot(n_rows, n_cols, index + 1)
          plt.imshow(instances[index], cmap='gray', interpolation='nearest')
          plt.axis('off')
          plt.title(class_names[y_train[index]], fontsize=12)
          if index == n_data-1:
            break
  plt.subplots_adjust(wspace=0.2, hspace=0.5)
  plt.show()

# %%
# Visualization of the First 50 Images

plot_digits(X_train, 30, images_per_row=10)

# %%
# Feature Scaling

X_train_scaled = X_train / 255.
X_val_scaled = X_val / 255.
X_test_scaled = X_test / 255.

# %% [markdown]
# # B - Model Building

# %% [markdown]
# ## B.1 - Without Dropout & Transfer Learning

# %% [markdown]
# For first scenario, we will create a simple ANN model.

# %%
# Clear Session
# %%time
seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

# Create Sequential API
model_1 = Sequential()
model_1.add(Flatten(input_shape=[28, 28]))
model_1.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_1.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_1.add(Dense(10, activation='softmax', kernel_initializer=tf.keras.initializers.GlorotNormal(seed)))

# Compile
model_1.compile(loss='sparse_categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
model_1.summary()

# Train the Model
history_model_1 = model_1.fit(X_train_scaled, y_train, epochs=30, validation_data=(X_val_scaled, y_val))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 10)                7850
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 8070 (31.52 KB)
# Trainable params: 8070 (31.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 1594/1594 [==============================] - 17s 6ms/step - loss: 0.6897 - accuracy: 0.7698 - val_loss: 0.5299 - val_accuracy: 0.8171
# Epoch 2/30
# 1594/1594 [==============================] - 5s 3ms/step - loss: 0.4895 - accuracy: 0.8308 - val_loss: 0.4838 - val_accuracy: 0.8289
# Epoch 3/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4566 - accuracy: 0.8418 - val_loss: 0.4888 - val_accuracy: 0.8222
# Epoch 4/30
# 1594/1594 [==============================] - 6s 3ms/step - loss: 0.4342 - accuracy: 0.8477 - val_loss: 0.4501 - val_accuracy: 0.8414
# Epoch 5/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4202 - accuracy: 0.8537 - val_loss: 0.4621 - val_accuracy: 0.8358
# Epoch 6/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4065 - accuracy: 0.8581 - val_loss: 0.4403 - val_accuracy: 0.8433
# Epoch 7/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3983 - accuracy: 0.8593 - val_loss: 0.4325 - val_accuracy: 0.8456
# Epoch 8/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3924 - accuracy: 0.8605 - val_loss: 0.4296 - val_accuracy: 0.8489
# Epoch 9/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3868 - accuracy: 0.8631 - val_loss: 0.4277 - val_accuracy: 0.8492
# Epoch 10/30
# 1594/1594 [==============================] - 5s 3ms/step - loss: 0.3828 - accuracy: 0.8629 - val_loss: 0.4142 - val_accuracy: 0.8546
# Epoch 11/30
# 1594/1594 [==============================] - 9s 5ms/step - loss: 0.3765 - accuracy: 0.8660 - val_loss: 0.4390 - val_accuracy: 0.8397
# Epoch 12/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3726 - accuracy: 0.8671 - val_loss: 0.4127 - val_accuracy: 0.8531
# Epoch 13/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3699 - accuracy: 0.8667 - val_loss: 0.4101 - val_accuracy: 0.8550
# Epoch 14/30
# 1594/1594 [==============================] - 5s 3ms/step - loss: 0.3644 - accuracy: 0.8682 - val_loss: 0.4164 - val_accuracy: 0.8536
# Epoch 15/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3621 - accuracy: 0.8690 - val_loss: 0.4111 - val_accuracy: 0.8558
# Epoch 16/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3589 - accuracy: 0.8708 - val_loss: 0.4198 - val_accuracy: 0.8506
# Epoch 17/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3570 - accuracy: 0.8713 - val_loss: 0.4156 - val_accuracy: 0.8538
# Epoch 18/30
# 1594/1594 [==============================] - 5s 3ms/step - loss: 0.3535 - accuracy: 0.8738 - val_loss: 0.4177 - val_accuracy: 0.8530
# Epoch 19/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3521 - accuracy: 0.8729 - val_loss: 0.4241 - val_accuracy: 0.8534
# Epoch 20/30
# 1594/1594 [==============================] - 5s 3ms/step - loss: 0.3502 - accuracy: 0.8734 - val_loss: 0.4165 - val_accuracy: 0.8541
# Epoch 21/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3466 - accuracy: 0.8749 - val_loss: 0.4262 - val_accuracy: 0.8476
# Epoch 22/30
# 1594/1594 [==============================] - 5s 3ms/step - loss: 0.3436 - accuracy: 0.8761 - val_loss: 0.4114 - val_accuracy: 0.8561
# Epoch 23/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3440 - accuracy: 0.8756 - val_loss: 0.4216 - val_accuracy: 0.8527
# Epoch 24/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3411 - accuracy: 0.8765 - val_loss: 0.4244 - val_accuracy: 0.8532
# Epoch 25/30
# 1594/1594 [==============================] - 7s 4ms/step - loss: 0.3379 - accuracy: 0.8771 - val_loss: 0.4070 - val_accuracy: 0.8553
# Epoch 26/30
# 1594/1594 [==============================] - 6s 3ms/step - loss: 0.3378 - accuracy: 0.8767 - val_loss: 0.4016 - val_accuracy: 0.8583
# Epoch 27/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3353 - accuracy: 0.8791 - val_loss: 0.4132 - val_accuracy: 0.8531
# Epoch 28/30
# 1594/1594 [==============================] - 5s 3ms/step - loss: 0.3345 - accuracy: 0.8783 - val_loss: 0.4076 - val_accuracy: 0.8580
# Epoch 29/30
# 1594/1594 [==============================] - 6s 3ms/step - loss: 0.3353 - accuracy: 0.8787 - val_loss: 0.4094 - val_accuracy: 0.8564
# Epoch 30/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.3324 - accuracy: 0.8791 - val_loss: 0.4382 - val_accuracy: 0.8502
# CPU times: user 3min 12s, sys: 15.9 s, total: 3min 28s
# Wall time: 3min 28s

# %%
# Plot Training Results

history_model_1 = pd.DataFrame(history_model_1.history)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.lineplot(data=history_model_1[['accuracy', 'val_accuracy']])
plt.grid()
plt.title('Accuracy vs Val-Accuracy')

plt.subplot(1, 2, 2)
sns.lineplot(data=history_model_1[['loss', 'val_loss']])
plt.grid()
plt.title('Loss vs Val-Loss')
plt.show()

# %% [markdown]
# It can be seen that out model is overfit during the training. To improve this model, in the next scenarios we will add Dropout layer and Transfer Learning.

# %% [markdown]
# ## B.2 - Add Dropout

# %% [markdown]
# For the second scenario, we will add Dropout Layer to reduce overfitting.

# %%
# Clear Session
# %%time
seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

# Create Sequential API
model_2 = Sequential()
model_2.add(Flatten(input_shape=[28, 28]))
model_2.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_2.add(Dropout(0.1, seed=seed))
model_2.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_2.add(Dropout(0.1, seed=seed))
model_2.add(Dense(10, activation='softmax', kernel_initializer=tf.keras.initializers.GlorotNormal(seed)))

# Compile
model_2.compile(loss='sparse_categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
model_2.summary()

# Train the Model
history_model_2 = model_2.fit(X_train_scaled, y_train, epochs=30, validation_data=(X_val_scaled, y_val))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 10)                7850
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 8070 (31.52 KB)
# Trainable params: 8070 (31.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 1594/1594 [==============================] - 7s 4ms/step - loss: 1.0010 - accuracy: 0.6366 - val_loss: 0.6369 - val_accuracy: 0.7704
# Epoch 2/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.7390 - accuracy: 0.7239 - val_loss: 0.5484 - val_accuracy: 0.8103
# Epoch 3/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.6558 - accuracy: 0.7595 - val_loss: 0.5117 - val_accuracy: 0.8201
# Epoch 4/30
# 1594/1594 [==============================] - 6s 3ms/step - loss: 0.6086 - accuracy: 0.7759 - val_loss: 0.4889 - val_accuracy: 0.8268
# Epoch 5/30
# 1594/1594 [==============================] - 7s 5ms/step - loss: 0.5823 - accuracy: 0.7874 - val_loss: 0.4920 - val_accuracy: 0.8243
# Epoch 6/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.5675 - accuracy: 0.7925 - val_loss: 0.4723 - val_accuracy: 0.8314
# Epoch 7/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.5538 - accuracy: 0.7986 - val_loss: 0.4594 - val_accuracy: 0.8391
# Epoch 8/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.5452 - accuracy: 0.8007 - val_loss: 0.4485 - val_accuracy: 0.8438
# Epoch 9/30
# 1594/1594 [==============================] - 7s 4ms/step - loss: 0.5357 - accuracy: 0.8056 - val_loss: 0.4676 - val_accuracy: 0.8313
# Epoch 10/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.5303 - accuracy: 0.8073 - val_loss: 0.4497 - val_accuracy: 0.8410
# Epoch 11/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.5278 - accuracy: 0.8092 - val_loss: 0.4556 - val_accuracy: 0.8387
# Epoch 12/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.5250 - accuracy: 0.8096 - val_loss: 0.4432 - val_accuracy: 0.8437
# Epoch 13/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.5193 - accuracy: 0.8127 - val_loss: 0.4396 - val_accuracy: 0.8444
# Epoch 14/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.5114 - accuracy: 0.8164 - val_loss: 0.4389 - val_accuracy: 0.8460
# Epoch 15/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.5050 - accuracy: 0.8168 - val_loss: 0.4455 - val_accuracy: 0.8433
# Epoch 16/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.5028 - accuracy: 0.8182 - val_loss: 0.4524 - val_accuracy: 0.8406
# Epoch 17/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4986 - accuracy: 0.8212 - val_loss: 0.4475 - val_accuracy: 0.8390
# Epoch 18/30
# 1594/1594 [==============================] - 5s 3ms/step - loss: 0.4992 - accuracy: 0.8197 - val_loss: 0.4414 - val_accuracy: 0.8458
# Epoch 19/30
# 1594/1594 [==============================] - 7s 4ms/step - loss: 0.4907 - accuracy: 0.8241 - val_loss: 0.4460 - val_accuracy: 0.8437
# Epoch 20/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4911 - accuracy: 0.8245 - val_loss: 0.4500 - val_accuracy: 0.8434
# Epoch 21/30
# 1594/1594 [==============================] - 7s 4ms/step - loss: 0.4853 - accuracy: 0.8259 - val_loss: 0.4419 - val_accuracy: 0.8411
# Epoch 22/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4839 - accuracy: 0.8249 - val_loss: 0.4503 - val_accuracy: 0.8374
# Epoch 23/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4884 - accuracy: 0.8246 - val_loss: 0.4574 - val_accuracy: 0.8370
# Epoch 24/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4827 - accuracy: 0.8258 - val_loss: 0.4329 - val_accuracy: 0.8507
# Epoch 25/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4773 - accuracy: 0.8288 - val_loss: 0.4376 - val_accuracy: 0.8454
# Epoch 26/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4786 - accuracy: 0.8282 - val_loss: 0.4517 - val_accuracy: 0.8411
# Epoch 27/30
# 1594/1594 [==============================] - 7s 4ms/step - loss: 0.4761 - accuracy: 0.8305 - val_loss: 0.4545 - val_accuracy: 0.8362
# Epoch 28/30
# 1594/1594 [==============================] - 5s 3ms/step - loss: 0.4742 - accuracy: 0.8287 - val_loss: 0.4564 - val_accuracy: 0.8336
# Epoch 29/30
# 1594/1594 [==============================] - 7s 4ms/step - loss: 0.4685 - accuracy: 0.8322 - val_loss: 0.4329 - val_accuracy: 0.8483
# Epoch 30/30
# 1594/1594 [==============================] - 6s 4ms/step - loss: 0.4663 - accuracy: 0.8305 - val_loss: 0.4448 - val_accuracy: 0.8422
# CPU times: user 3min 15s, sys: 14.6 s, total: 3min 30s
# Wall time: 3min 23s

# %%
# Plot Training Results

history_model_2 = pd.DataFrame(history_model_2.history)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.lineplot(data=history_model_2[['accuracy', 'val_accuracy']])
plt.grid()
plt.title('Accuracy vs Val-Accuracy')

plt.subplot(1, 2, 2)
sns.lineplot(data=history_model_2[['loss', 'val_loss']])
plt.grid()
plt.title('Loss vs Val-Loss')
plt.show()

# %% [markdown]
# Adding Dropout Layer was succesfully reduce the overfitting. Both loss on train-set and val-set decreasing as epochs increasing.

# %% [markdown]
# ## B.3 - Transfer Learning

# %% [markdown]
# For last scenario, we will implement Transfer Learning. Transfer learning is a technique where a model trained on one task or dataset is adapted and fine-tuned for a different but related task or dataset. It leverages knowledge gained from the source task to improve performance on the target task.
#
# We will add `EfficientNet` layers into our model. Please see this [source](https://keras.io/api/applications/) or [source](https://www.tensorflow.org/api_docs/python/tf/keras/applications/) for more details.

# %% [markdown]
# <img src='https://miro.medium.com/v2/resize:fit:1100/format:png/1*gw37manvc-f9xuFXx9_8WA.png'>

# %% [markdown]
# First, we will change our dataset so it can be processed by `EfficientNet`. `EfficientNet` was trained on dataset called [imagenet](https://www.image-net.org/) with millions of images. The requirement of `EfficientNet` is the image should have exactly 3 inputs channels, and width and height should be no smaller than 32.

# %%
# Change the Image Dimension

## Step 1 : Expand 1 dimensions
X_train_new = np.expand_dims(X_train, -1)
X_val_new = np.expand_dims(X_val, -1)
X_test_new = np.expand_dims(X_test, -1)

## Step 2 : Convert to RGB
X_train_new = tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_train_new))
X_val_new = tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_val_new))
X_test_new = tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_test_new))

## Step 3 : Resize the image
X_train_new = tf.image.resize(X_train_new, (32, 32))
X_val_new = tf.image.resize(X_val_new, (32, 32))
X_test_new = tf.image.resize(X_test_new, (32, 32))

print('Train size - Before : ', X_train_scaled.shape, ' - After : ', X_train_new.shape)
print('Val size   - Before : ', X_val_scaled.shape, '  - After : ', X_val_new.shape)
print('Test size  - Before : ', X_test_scaled.shape, ' - After : ', X_test_new.shape)
# Out:
# Train size - Before :  (51000, 28, 28)  - After :  (51000, 32, 32, 3)
# Val size   - Before :  (9000, 28, 28)   - After :  (9000, 32, 32, 3)
# Test size  - Before :  (10000, 28, 28)  - After :  (10000, 32, 32, 3)

# %%
# Download the EfficientNet Model
pretrained_model= tf.keras.applications.EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=(32, 32, 3)
)

# Freeze the Lower Layer
pretrained_model.trainable= False

# Preprocessing
X_train_new = tf.keras.applications.efficientnet.preprocess_input(X_train_new)
X_val_new = tf.keras.applications.efficientnet.preprocess_input(X_val_new)
X_test_new = tf.keras.applications.efficientnet.preprocess_input(X_test_new)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
# Clear Session
# %%time
seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

# Create Sequential API
model_3 = Sequential()
model_3.add(pretrained_model)
model_3.add(Flatten())
model_3.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_3.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_3.add(Dense(10, activation='softmax', kernel_initializer=tf.keras.initializers.GlorotNormal(seed)))

# Compile
model_3.compile(loss='sparse_categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
model_3.summary()

# Train the Model
history_model_3 = model_3.fit(X_train_new, y_train, epochs=30, validation_data=(X_val_new, y_val))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 1, 1, 1280)        4049571
#  )
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 10)                12810
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 4062601 (15.50 MB)
# Trainable params: 13030 (50.90 KB)
# Non-trainable params: 4049571 (15.45 MB)
# _________________________________________________________________
# Epoch 1/30
# 1594/1594 [==============================] - 33s 14ms/step - loss: 0.9734 - accuracy: 0.6585 - val_loss: 0.6600 - val_accuracy: 0.7662
# Epoch 2/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.6662 - accuracy: 0.7627 - val_loss: 0.5712 - val_accuracy: 0.8018
# Epoch 3/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.6137 - accuracy: 0.7817 - val_loss: 0.5550 - val_accuracy: 0.8058
# Epoch 4/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.5893 - accuracy: 0.7887 - val_loss: 0.5286 - val_accuracy: 0.8137
# Epoch 5/30
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.5626 - accuracy: 0.7983 - val_loss: 0.5367 - val_accuracy: 0.8090
# Epoch 6/30
# 1594/1594 [==============================] - 21s 13ms/step - loss: 0.5530 - accuracy: 0.8004 - val_loss: 0.5261 - val_accuracy: 0.8146
# Epoch 7/30
# 1594/1594 [==============================] - 18s 12ms/step - loss: 0.5395 - accuracy: 0.8048 - val_loss: 0.4932 - val_accuracy: 0.8263
# Epoch 8/30
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.5337 - accuracy: 0.8089 - val_loss: 0.4824 - val_accuracy: 0.8296
# Epoch 9/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.5249 - accuracy: 0.8101 - val_loss: 0.4982 - val_accuracy: 0.8277
# Epoch 10/30
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.5208 - accuracy: 0.8128 - val_loss: 0.5044 - val_accuracy: 0.8221
# Epoch 11/30
# 1594/1594 [==============================] - 18s 12ms/step - loss: 0.5141 - accuracy: 0.8146 - val_loss: 0.4776 - val_accuracy: 0.8296
# Epoch 12/30
# 1594/1594 [==============================] - 18s 12ms/step - loss: 0.5103 - accuracy: 0.8178 - val_loss: 0.4969 - val_accuracy: 0.8221
# Epoch 13/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.5053 - accuracy: 0.8186 - val_loss: 0.4743 - val_accuracy: 0.8317
# Epoch 14/30
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.4986 - accuracy: 0.8194 - val_loss: 0.4766 - val_accuracy: 0.8309
# Epoch 15/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.4985 - accuracy: 0.8200 - val_loss: 0.4869 - val_accuracy: 0.8278
# Epoch 16/30
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.4938 - accuracy: 0.8231 - val_loss: 0.4746 - val_accuracy: 0.8296
# Epoch 17/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.4950 - accuracy: 0.8220 - val_loss: 0.4867 - val_accuracy: 0.8279
# Epoch 18/30
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.4873 - accuracy: 0.8240 - val_loss: 0.4799 - val_accuracy: 0.8296
# Epoch 19/30
# 1594/1594 [==============================] - 17s 11ms/step - loss: 0.4871 - accuracy: 0.8243 - val_loss: 0.4838 - val_accuracy: 0.8280
# Epoch 20/30
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.4858 - accuracy: 0.8247 - val_loss: 0.4699 - val_accuracy: 0.8313
# Epoch 21/30
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.4811 - accuracy: 0.8255 - val_loss: 0.4543 - val_accuracy: 0.8364
# Epoch 22/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.4782 - accuracy: 0.8274 - val_loss: 0.4585 - val_accuracy: 0.8373
# Epoch 23/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.4748 - accuracy: 0.8299 - val_loss: 0.4625 - val_accuracy: 0.8352
# Epoch 24/30
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.4710 - accuracy: 0.8308 - val_loss: 0.4818 - val_accuracy: 0.8313
# Epoch 25/30
# 1594/1594 [==============================] - 20s 12ms/step - loss: 0.4671 - accuracy: 0.8328 - val_loss: 0.4599 - val_accuracy: 0.8373
# Epoch 26/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.4706 - accuracy: 0.8310 - val_loss: 0.4695 - val_accuracy: 0.8359
# Epoch 27/30
# 1594/1594 [==============================] - 21s 13ms/step - loss: 0.4663 - accuracy: 0.8319 - val_loss: 0.4521 - val_accuracy: 0.8383
# Epoch 28/30
# 1594/1594 [==============================] - 18s 11ms/step - loss: 0.4628 - accuracy: 0.8320 - val_loss: 0.4542 - val_accuracy: 0.8369
# Epoch 29/30
# 1594/1594 [==============================] - 19s 12ms/step - loss: 0.4618 - accuracy: 0.8328 - val_loss: 0.4405 - val_accuracy: 0.8448
# Epoch 30/30
# 1594/1594 [==============================] - 18s 12ms/step - loss: 0.4630 - accuracy: 0.8333 - val_loss: 0.4754 - val_accuracy: 0.8331
# CPU times: user 9min 27s, sys: 18.2 s, total: 9min 46s
# Wall time: 10min 29s

# %%
# Plot Training Results

history_model_3 = pd.DataFrame(history_model_3.history)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.lineplot(data=history_model_3[['accuracy', 'val_accuracy']])
plt.grid()
plt.title('Accuracy vs Val-Accuracy')

plt.subplot(1, 2, 2)
sns.lineplot(data=history_model_3[['loss', 'val_loss']])
plt.grid()
plt.title('Loss vs Val-Loss')
plt.show()

# %% [markdown]
# **INSIGHTS**
#
# 1. It can be seen, our model is considered as good-fit.
#
# 2. Even though, there is no `Dropout` Layer or `BatchNormalization` Layer, the model can still convergence.
#
# 3. Both losses are still on a downward trend so there is a possibility that if the number of epochs is increased, the model could still have even higher performance.
