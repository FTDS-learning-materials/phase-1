# %% [markdown]
# # Phase 1 - Week 4 - Day 2 AM - Training Artificial Neural Network: Part 1

# %% [markdown]
# **The purpose of this notebook is to demonstrate the effect of selecting the sigmoid activation function so that a vanishing gradient occurs.**
#
# Then an experiment will be carried out if the activation function is changed to ReLU.

# %% [markdown]
# The vanishing gradient problem occurs when gradients (slopes) during backpropagation **become extremely small** as they are propagated backward through the layers of a deep neural network.
#
# When gradients are very small, the updates to the network's parameters become negligible, leading to slow or stalled training.
#
# The vanishing gradient problem is typically caused by activation functions like the sigmoid or hyperbolic tangent (tanh) functions, which squash input values into a small range (e.g., between 0 and 1 or -1 and 1). When these functions are repeatedly applied in deep networks, gradients can shrink to near-zero values.
#
# As a result, deep layers of the network fail to learn meaningful representations from the data, and the network may not converge to a good solution.
#
# **The model weights can become 0 in the training phase.**

# %% [markdown]
# # A. Import Libraries & Data Loading

# %%
# Import Libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from tensorflow.keras import Sequential
from tensorflow.keras.initializers import RandomNormal, HeNormal
from tensorflow.keras.layers import Input, Dense

# %% [markdown]
# In this experiment, we will create an artificial dataset regarding Binary Classification

# %%
# Make Dataset

X, y = make_circles(n_samples=1000, factor=0.5, noise=0.1)

plt.figure(figsize=(8,6))
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
# Data Splitting

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
print('Train size : ', X_train.shape)
print('Test size  : ', X_test.shape)
# Out:
# Train size :  (850, 2)
# Test size  :  (150, 2)

# %% [markdown]
# # B. Model with Sigmoid

# %% [markdown]
# For first model, we will create an ANN model with configuration :
#
# * 2 input neuron (based on the number of features)
# * 5 hidden layer
# * Each hidden layer will contains 5 hidden neurons
# * Weight Initialization : Random Normal
# * Loss function : Binary Cross Entropy
# * Optimizer : Adam

# %%
# Create ANN Model

seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

initializer = RandomNormal(mean=0, stddev=1, seed=seed)
loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()

model_sigmoid = Sequential([
    Input(shape=(2,), name='input-layer'),
    Dense(5, activation='sigmoid', kernel_initializer=initializer, name='hidden-layer-1'),
    Dense(5, activation='sigmoid', kernel_initializer=initializer, name='hidden-layer-2'),
    Dense(5, activation='sigmoid', kernel_initializer=initializer, name='hidden-layer-3'),
    Dense(1, activation="sigmoid", kernel_initializer=initializer, name='output-layer')
])

# Compile
model_sigmoid.compile(loss=loss_function, optimizer=optimizer, metrics=['accuracy'])
model_sigmoid.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden-layer-1 (Dense)      (None, 5)                 15
#
#  hidden-layer-2 (Dense)      (None, 5)                 30
#
#  hidden-layer-3 (Dense)      (None, 5)                 30
#
#  output-layer (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 81 (324.00 Byte)
# Trainable params: 81 (324.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the ANN Model

model_sigmoid.fit(X_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 7s 8ms/step - loss: 0.7010 - accuracy: 0.4941
# Epoch 2/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6971 - accuracy: 0.4941
# Epoch 3/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6950 - accuracy: 0.4847
# Epoch 4/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6944 - accuracy: 0.4235
# Epoch 5/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6938 - accuracy: 0.4812
# Epoch 6/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6936 - accuracy: 0.5212
# Epoch 7/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6936 - accuracy: 0.5224
# Epoch 8/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6935 - accuracy: 0.5341
# Epoch 9/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6936 - accuracy: 0.5859
# Epoch 10/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6936 - accuracy: 0.5494
# Epoch 11/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6933 - accuracy: 0.5600
# Epoch 12/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6934 - accuracy: 0.5494
# Epoch 13/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.6165
# Epoch 14/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6930 - accuracy: 0.6165
# Epoch 15/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6931 - accuracy: 0.6447
# Epoch 16/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6930 - accuracy: 0.6176
# Epoch 17/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6930 - accuracy: 0.5765
# Epoch 18/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6929 - accuracy: 0.6188
# Epoch 19/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6930 - accuracy: 0.5988
# Epoch 20/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6927 - accuracy: 0.6224
# Epoch 21/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6927 - accuracy: 0.6176
# Epoch 22/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6926 - accuracy: 0.6271
# Epoch 23/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6927 - accuracy: 0.6235
# Epoch 24/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6926 - accuracy: 0.5929
# Epoch 25/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6927 - accuracy: 0.6224
# Epoch 26/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.6924 - accuracy: 0.6247
# Epoch 27/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6925 - accuracy: 0.5588
# Epoch 28/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6928 - accuracy: 0.6106
# Epoch 29/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6922 - accuracy: 0.6412
# Epoch 30/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.6923 - accuracy: 0.5824
# Epoch 31/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6921 - accuracy: 0.6035
# Epoch 32/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6920 - accuracy: 0.6282
# Epoch 33/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.6919 - accuracy: 0.5976
# Epoch 34/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6920 - accuracy: 0.5600
# Epoch 35/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.6918 - accuracy: 0.6200
# Epoch 36/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6917 - accuracy: 0.6200
# Epoch 37/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6917 - accuracy: 0.6318
# Epoch 38/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6916 - accuracy: 0.6388
# Epoch 39/100
# 27/27 [==============================] - 0s 11ms/step - loss: 0.6914 - accuracy: 0.6224
# Epoch 40/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.6914 - accuracy: 0.6365
# Epoch 41/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6913 - accuracy: 0.6047
# Epoch 42/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6912 - accuracy: 0.5812
# Epoch 43/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6911 - accuracy: 0.5988
# Epoch 44/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6910 - accuracy: 0.6024
# Epoch 45/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6913 - accuracy: 0.6235
# Epoch 46/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6908 - accuracy: 0.6153
# Epoch 47/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.6907 - accuracy: 0.6271
# Epoch 48/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6906 - accuracy: 0.5800
# Epoch 49/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6905 - accuracy: 0.5976
# Epoch 50/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6903 - accuracy: 0.5941
# Epoch 51/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6901 - accuracy: 0.6071
# Epoch 52/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6901 - accuracy: 0.6259
# Epoch 53/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6900 - accuracy: 0.5859
# Epoch 54/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6899 - accuracy: 0.6141
# Epoch 55/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6897 - accuracy: 0.5706
# Epoch 56/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6893 - accuracy: 0.5894
# Epoch 57/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6892 - accuracy: 0.6000
# Epoch 58/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6893 - accuracy: 0.6259
# Epoch 59/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6891 - accuracy: 0.5906
# Epoch 60/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6887 - accuracy: 0.6188
# Epoch 61/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6884 - accuracy: 0.6082
# Epoch 62/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6883 - accuracy: 0.6106
# Epoch 63/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6884 - accuracy: 0.5976
# Epoch 64/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6879 - accuracy: 0.6094
# Epoch 65/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.6035
# Epoch 66/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6874 - accuracy: 0.5812
# Epoch 67/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6873 - accuracy: 0.6071
# Epoch 68/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6867 - accuracy: 0.6047
# Epoch 69/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6865 - accuracy: 0.6035
# Epoch 70/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6862 - accuracy: 0.5871
# Epoch 71/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6859 - accuracy: 0.5929
# Epoch 72/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6856 - accuracy: 0.5882
# Epoch 73/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6852 - accuracy: 0.5882
# Epoch 74/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6849 - accuracy: 0.6024
# Epoch 75/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6846 - accuracy: 0.5953
# Epoch 76/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6843 - accuracy: 0.5941
# Epoch 77/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6840 - accuracy: 0.6071
# Epoch 78/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6834 - accuracy: 0.5929
# Epoch 79/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.6832 - accuracy: 0.5941
# Epoch 80/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6827 - accuracy: 0.5953
# Epoch 81/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6825 - accuracy: 0.6000
# Epoch 82/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6821 - accuracy: 0.5824
# Epoch 83/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6816 - accuracy: 0.5871
# Epoch 84/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6809 - accuracy: 0.5918
# Epoch 85/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6804 - accuracy: 0.5906
# Epoch 86/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6800 - accuracy: 0.5941
# Epoch 87/100
# 27/27 [==============================] - 0s 11ms/step - loss: 0.6796 - accuracy: 0.5906
# Epoch 88/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6792 - accuracy: 0.6082
# Epoch 89/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6784 - accuracy: 0.6012
# Epoch 90/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6780 - accuracy: 0.6000
# Epoch 91/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6773 - accuracy: 0.5929
# Epoch 92/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6769 - accuracy: 0.5882
# Epoch 93/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6764 - accuracy: 0.5894
# Epoch 94/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6757 - accuracy: 0.5965
# Epoch 95/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6751 - accuracy: 0.5882
# Epoch 96/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6746 - accuracy: 0.5906
# Epoch 97/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6742 - accuracy: 0.6000
# Epoch 98/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6733 - accuracy: 0.6000
# Epoch 99/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6726 - accuracy: 0.6012
# Epoch 100/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6721 - accuracy: 0.5894

# %%
# Predict test-set

model_sigmoid.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6780 - accuracy: 0.5400
# [0.6780008673667908, 0.5400000214576721]

# %% [markdown]
# Unfortunately, the performance of the model using the sigmoid is too low when tested with a test-set. The accuracy value only reaches 54 %.

# %% [markdown]
# # C. Model with ReLU

# %% [markdown]
# Let's improve our model by changing :
#
# * The activation function to ReLU
# * Weight initialization to HeNormal (HeNormal is more suitable for use by ReLU for weight initialization techniques).

# %%
# Create ANN Model

seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

initializer = HeNormal(seed=seed)
loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()

model_relu = Sequential([
    Input(shape=(2,), name='input-layer'),
    Dense(5, activation='relu', kernel_initializer=initializer, name='hidden-layer-1'),
    Dense(5, activation='relu', kernel_initializer=initializer, name='hidden-layer-2'),
    Dense(5, activation='relu', kernel_initializer=initializer, name='hidden-layer-3'),
    Dense(1, activation="sigmoid", kernel_initializer=initializer, name='output-layer')
])

# Compile
model_relu.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])
model_relu.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden-layer-1 (Dense)      (None, 5)                 15
#
#  hidden-layer-2 (Dense)      (None, 5)                 30
#
#  hidden-layer-3 (Dense)      (None, 5)                 30
#
#  output-layer (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 81 (324.00 Byte)
# Trainable params: 81 (324.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the ANN Model

model_relu.fit(X_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 2s 7ms/step - loss: 0.8022 - accuracy: 0.4800
# Epoch 2/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.7520 - accuracy: 0.4824
# Epoch 3/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.7212 - accuracy: 0.4741
# Epoch 4/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7001 - accuracy: 0.4682
# Epoch 5/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6829 - accuracy: 0.4647
# Epoch 6/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6680 - accuracy: 0.4812
# Epoch 7/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6540 - accuracy: 0.5400
# Epoch 8/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6406 - accuracy: 0.5800
# Epoch 9/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6273 - accuracy: 0.6000
# Epoch 10/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6141 - accuracy: 0.6012
# Epoch 11/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6004 - accuracy: 0.6271
# Epoch 12/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5873 - accuracy: 0.6518
# Epoch 13/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5737 - accuracy: 0.6706
# Epoch 14/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5606 - accuracy: 0.6953
# Epoch 15/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5475 - accuracy: 0.7341
# Epoch 16/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5346 - accuracy: 0.7541
# Epoch 17/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5223 - accuracy: 0.7635
# Epoch 18/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5104 - accuracy: 0.7859
# Epoch 19/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4992 - accuracy: 0.7953
# Epoch 20/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4884 - accuracy: 0.8035
# Epoch 21/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4781 - accuracy: 0.8082
# Epoch 22/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4670 - accuracy: 0.8165
# Epoch 23/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4568 - accuracy: 0.8259
# Epoch 24/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4458 - accuracy: 0.8318
# Epoch 25/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4352 - accuracy: 0.8376
# Epoch 26/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4237 - accuracy: 0.8376
# Epoch 27/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4126 - accuracy: 0.8435
# Epoch 28/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4011 - accuracy: 0.8529
# Epoch 29/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3888 - accuracy: 0.8612
# Epoch 30/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3764 - accuracy: 0.8671
# Epoch 31/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3628 - accuracy: 0.8824
# Epoch 32/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3500 - accuracy: 0.8859
# Epoch 33/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3380 - accuracy: 0.8929
# Epoch 34/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3264 - accuracy: 0.8953
# Epoch 35/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3144 - accuracy: 0.9059
# Epoch 36/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2977 - accuracy: 0.9094
# Epoch 37/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2697 - accuracy: 0.9341
# Epoch 38/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2383 - accuracy: 0.9506
# Epoch 39/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2139 - accuracy: 0.9635
# Epoch 40/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1944 - accuracy: 0.9682
# Epoch 41/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1794 - accuracy: 0.9682
# Epoch 42/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1660 - accuracy: 0.9765
# Epoch 43/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1532 - accuracy: 0.9765
# Epoch 44/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1425 - accuracy: 0.9776
# Epoch 45/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1327 - accuracy: 0.9788
# Epoch 46/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1233 - accuracy: 0.9788
# Epoch 47/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1145 - accuracy: 0.9835
# Epoch 48/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1065 - accuracy: 0.9847
# Epoch 49/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0997 - accuracy: 0.9871
# Epoch 50/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9871
# Epoch 51/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0873 - accuracy: 0.9859
# Epoch 52/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 0.9871
# Epoch 53/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0778 - accuracy: 0.9871
# Epoch 54/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0746 - accuracy: 0.9882
# Epoch 55/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0698 - accuracy: 0.9871
# Epoch 56/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0666 - accuracy: 0.9882
# Epoch 57/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0636 - accuracy: 0.9882
# Epoch 58/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0613 - accuracy: 0.9882
# Epoch 59/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0587 - accuracy: 0.9894
# Epoch 60/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0564 - accuracy: 0.9894
# Epoch 61/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9906
# Epoch 62/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 0.9894
# Epoch 63/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0501 - accuracy: 0.9906
# Epoch 64/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0483 - accuracy: 0.9906
# Epoch 65/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9918
# Epoch 66/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0457 - accuracy: 0.9906
# Epoch 67/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 0.9894
# Epoch 68/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 0.9918
# Epoch 69/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0418 - accuracy: 0.9918
# Epoch 70/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0411 - accuracy: 0.9918
# Epoch 71/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 0.9918
# Epoch 72/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0389 - accuracy: 0.9918
# Epoch 73/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0381 - accuracy: 0.9929
# Epoch 74/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0380 - accuracy: 0.9929
# Epoch 75/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 0.9894
# Epoch 76/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0359 - accuracy: 0.9929
# Epoch 77/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0352 - accuracy: 0.9918
# Epoch 78/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0352 - accuracy: 0.9918
# Epoch 79/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0344 - accuracy: 0.9929
# Epoch 80/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9929
# Epoch 81/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9929
# Epoch 82/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9929
# Epoch 83/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9929
# Epoch 84/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9918
# Epoch 85/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0312 - accuracy: 0.9918
# Epoch 86/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9941
# Epoch 87/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9929
# Epoch 88/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0298 - accuracy: 0.9941
# Epoch 89/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0293 - accuracy: 0.9929
# Epoch 90/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9941
# Epoch 91/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9918
# Epoch 92/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0284 - accuracy: 0.9918
# Epoch 93/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0283 - accuracy: 0.9929
# Epoch 94/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 0.9941
# Epoch 95/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0280 - accuracy: 0.9918
# Epoch 96/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9918
# Epoch 97/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 0.9929
# Epoch 98/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 0.9941
# Epoch 99/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9918
# Epoch 100/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0263 - accuracy: 0.9918

# %%
# Predict test-set

model_relu.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0371 - accuracy: 0.9800
# [0.03707178309559822, 0.9800000190734863]

# %% [markdown]
# After changing the activation function and weight initialization, it can be seen that the performance of the train and test has increased drastically, even approaching perfect conditions. Hooray.

# %% [markdown]
# # D. The Gradient

# %% [markdown]
# Let's look at the gradient differences between models that use the Sigmoid activation function with ReLU. Let's prove whether it is true that the Sigmoid activation function leads to a vanish gradient or not.

# %%
# Create a Function to Store Weights from Each Epoch

def train_model(X, y, model, loss_function, optimizer, n_epochs=100, batch_size=32):
    "Run training loop manually"
    train_dataset = tf.data.Dataset.from_tensor_slices((X, y))
    train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

    gradhistory = []
    losshistory = []
    def recordweight():
        data = {}
        for g,w in zip(grads, model.trainable_weights):
            if '/kernel:' not in w.name:
                continue # skip bias
            name = w.name.split("/")[0]
            data[name] = g.numpy()
        gradhistory.append(data)
        losshistory.append(loss_value.numpy())
    for epoch in range(n_epochs):
        for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
            with tf.GradientTape() as tape:
                y_pred = model(x_batch_train, training=True)
                loss_value = loss_function(y_batch_train, y_pred)

            grads = tape.gradient(loss_value, model.trainable_weights)
            optimizer.apply_gradients(zip(grads, model.trainable_weights))

            if step == 0:
                recordweight()

    recordweight()
    return gradhistory, losshistory

# %%
# Create a Function to Plot the Gradients of Each Epoch

def plot_gradient(gradhistory, losshistory):
    "Plot gradient mean and sd across epochs"
    fig, ax = plt.subplots(1, 3, sharex=True, constrained_layout=True, figsize=(15, 4))
    ax[0].set_title("Mean gradient")
    for key in gradhistory[0]:
        ax[0].plot(range(len(gradhistory)), [w[key].mean() for w in gradhistory], label=key)
    ax[0].legend()
    ax[1].set_title("S.D.")
    for key in gradhistory[0]:
        ax[1].semilogy(range(len(gradhistory)), [w[key].std() for w in gradhistory], label=key)
    ax[1].legend()
    ax[2].set_title("Loss")
    ax[2].plot(range(len(losshistory)), losshistory)
    plt.show()

# %%
# Check the Gradients on Sigmoid Model and ReLU Model

# %%time
loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()
gradhistory_sigmoid, losshistory_sigmoid = train_model(X_train, y_train, model_sigmoid, loss_function, optimizer, n_epochs=100, batch_size=32)

loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()
gradhistory_relu, losshistory_relu = train_model(X_train, y_train, model_relu, loss_function, optimizer, n_epochs=100, batch_size=32)

print('-- Sigmoid Model -- ')
plot_gradient(gradhistory_sigmoid, losshistory_sigmoid)
print('')

print('-- ReLU Model -- ')
plot_gradient(gradhistory_relu, losshistory_relu)
print('')
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7bf510153a30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7bf510153a30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# -- Sigmoid Model --
# -- ReLU Model --
# CPU times: user 1min 42s, sys: 1.47 s, total: 1min 43s
# Wall time: 1min 51s

# %% [markdown]
# **INSIGHTS :**
#
# 1. Sigmoid model :
#    * From the `Mean gradient` plot, it can be seen that only the gradients from the output layer has a fluctuating gradient.
#    * While the gradient of the other layers is around `0`.
#    * This causes the the loss value decreases slowly and even looks stagnant. This phenomenon is called vanishing gradient.
#
# 2. ReLU model :
#    * The gradient that comes from the ReLU model varies in each layer and tends to go up and down so it doesn't stagnate at `0`.
#    * This causes the loss values to change, allowing the model to reach its optimal point.
